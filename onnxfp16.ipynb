# %%
import onnx
import onnxruntime as ort
import cv2
import tensorflow as tf
import numpy as np
import time

# %%
session = ort.InferenceSession('models/model_fp16.onnx', None)
input_name = session.get_inputs()[0].name
output_thresh = session.get_outputs()[0].name
output_coords = session.get_outputs()[1].name

# %%
cap = cv2.VideoCapture(0)
num_frames = 0
start_time = time.time()
total_inference_time = 0
while cap.isOpened():
    _ , frame = cap.read()
    frame = frame[50:500, 50:500,:]

    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    resized = tf.image.resize(rgb, (120,120))
    img = np.expand_dims(resized/255,0)
    img = img.astype(np.float16)
    time1 = time.time()
    threshold = session.run([output_thresh], {input_name: img})
    coords = session.run([output_coords], {input_name: img})
    time2 = time.time()
    time3 = time2 - time1
    total_inference_time += time3  # Add current inference time to total inference time
    print(f"Inference time: {time3:.3f} s")
    output_threshh = np.array(threshold)
    output_coord = np.array(coords[0][0])
    yhat = output_threshh, output_coords

    
    if yhat[0] > 0.8: 
        # Controls the main rectangle
        cv2.rectangle(frame, 
                      tuple(np.multiply(output_coord[:2], [450,450]).astype(int)),
                      tuple(np.multiply(output_coord[2:], [450,450]).astype(int)), 
                            (255,0,0), 2)
        # Controls the label rectangle
        cv2.rectangle(frame, 
                      tuple(np.add(np.multiply(output_coord[:2], [450,450]).astype(int), 
                                    [0,-30])),
                      tuple(np.add(np.multiply(output_coord[:2], [450,450]).astype(int),
                                    [80,0])), 
                            (255,0,0), -1)
        
        # Controls the text rendered
        cv2.putText(frame, 'face', tuple(np.add(np.multiply(output_coord[:2], [450,450]).astype(int),
                                               [0,-5])),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
    
    cv2.imshow('EyeTrack', frame)

    num_frames += 1
    fps = num_frames / (time.time() - start_time)
    print(f'Frame rate: {fps:.2f} fps')
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

avg_inference_time = total_inference_time / num_frames
print(f'Total number of frames: {num_frames}')
print(f'Total elapsed time: {time.time() - start_time:.2f} s')
print(f'Average FPS: {num_frames / (time.time() - start_time):.2f} fps')
print(f'Average inference time: {avg_inference_time:.2f} s')
# Out:
# Inference time: 0.108 s
# Frame rate: 1.17 fps
# Inference time: 0.091 s
# Frame rate: 2.09 fps
# Inference time: 0.100 s
# Frame rate: 2.81 fps
# Inference time: 0.095 s
# Frame rate: 3.40 fps
# Inference time: 0.093 s
# Frame rate: 3.88 fps
# Inference time: 0.088 s
# Frame rate: 4.32 fps
# Inference time: 0.058 s
# Frame rate: 4.77 fps
# Inference time: 0.066 s
# Frame rate: 5.06 fps
# Inference time: 0.069 s
# Frame rate: 5.40 fps
# Inference time: 0.067 s
# Frame rate: 5.67 fps
# Inference time: 0.073 s
# Frame rate: 5.90 fps
# Inference time: 0.082 s
# Frame rate: 6.11 fps
# Inference time: 0.069 s
# Frame rate: 6.35 fps
# Inference time: 0.068 s
# Frame rate: 6.54 fps
# Inference time: 0.084 s
# Frame rate: 6.71 fps
# Inference time: 0.067 s
# Frame rate: 6.91 fps
# Inference time: 0.082 s
# Frame rate: 7.04 fps
# Inference time: 0.067 s
# Frame rate: 7.17 fps
# Inference time: 0.057 s
# Frame rate: 7.34 fps
# Inference time: 0.075 s
# Frame rate: 7.44 fps
# Inference time: 0.078 s
# Frame rate: 7.54 fps
# Inference time: 0.056 s
# Frame rate: 7.70 fps
# Inference time: 0.067 s
# Frame rate: 7.80 fps
# Inference time: 0.061 s
# Frame rate: 7.91 fps
# Inference time: 0.084 s
# Frame rate: 7.98 fps
# Inference time: 0.075 s
# Frame rate: 8.04 fps
# Inference time: 0.094 s
# Frame rate: 8.06 fps
# Inference time: 0.103 s
# Frame rate: 8.02 fps
# Inference time: 0.105 s
# Frame rate: 8.03 fps
# Inference time: 0.108 s
# Frame rate: 8.02 fps
# Inference time: 0.095 s
# Frame rate: 8.05 fps
# Inference time: 0.104 s
# Frame rate: 8.06 fps
# Inference time: 0.124 s
# Frame rate: 8.02 fps
# Inference time: 0.061 s
# Frame rate: 8.10 fps
# Inference time: 0.090 s
# Frame rate: 8.13 fps
# Inference time: 0.081 s
# Frame rate: 8.17 fps
# Inference time: 0.086 s
# Frame rate: 8.20 fps
# Inference time: 0.083 s
# Frame rate: 8.24 fps
# Inference time: 0.092 s
# Frame rate: 8.27 fps
# Inference time: 0.090 s
# Frame rate: 8.28 fps
# Inference time: 0.065 s
# Frame rate: 8.35 fps
# Inference time: 0.061 s
# Frame rate: 8.43 fps
# Inference time: 0.088 s
# Frame rate: 8.44 fps
# Inference time: 0.094 s
# Frame rate: 8.44 fps
# Inference time: 0.108 s
# Frame rate: 8.44 fps
# Inference time: 0.103 s
# Frame rate: 8.43 fps
# Inference time: 0.077 s
# Frame rate: 8.46 fps
# Inference time: 0.088 s
# Frame rate: 8.48 fps
# Inference time: 0.093 s
# Frame rate: 8.48 fps
# Inference time: 0.076 s
# Frame rate: 8.52 fps
# Inference time: 0.087 s
# Frame rate: 8.54 fps
# Inference time: 0.058 s
# Frame rate: 8.60 fps
# Inference time: 0.056 s
# Frame rate: 8.65 fps
# Inference time: 0.073 s
# Frame rate: 8.68 fps
# Inference time: 0.066 s
# Frame rate: 8.72 fps
# Inference time: 0.089 s
# Frame rate: 8.72 fps
# Inference time: 0.068 s
# Frame rate: 8.75 fps
# Inference time: 0.069 s
# Frame rate: 8.78 fps
# Inference time: 0.062 s
# Frame rate: 8.82 fps
# Inference time: 0.060 s
# Frame rate: 8.86 fps
# Inference time: 0.086 s
# Frame rate: 8.87 fps
# Inference time: 0.085 s
# Frame rate: 8.88 fps
# Total number of frames: 62
# Total elapsed time: 7.50 s
# Average FPS: 8.27 fps
# Average inference time: 0.08 s
